# %%
import os
import subprocess
import sys
from pathlib import Path

script_path = Path("train_td.py").resolve()

print(f"Running training script: {script_path}")

result = subprocess.run(
    [sys.executable, str(script_path)],
    cwd=str(script_path.parent),
    env=os.environ.copy(),
    capture_output=True,
    text=True,
)

if result.stdout:
    print(result.stdout)

if result.stderr:
    print("STDERR / ERRORS:")
    print(result.stderr)

if result.returncode != 0:
    raise subprocess.CalledProcessError(result.returncode, result.args)

print("Training finished successfully.")
# Out:
# Running training script: C:\Users\ujwal\OneDrive\Documents\Github\Reinforcement-learning\RL_LLM\0_what_is_RL\02_actor_critique\td_learning\train_td.py
# Episode  100 | P(0)=0.010 | P(1)=0.990 | V=1.004 | TD=-0.004
# Episode  200 | P(0)=0.010 | P(1)=0.990 | V=1.000 | TD=-0.000
# Episode  300 | P(0)=0.001 | P(1)=0.999 | V=1.000 | TD=-0.000
# Episode  400 | P(0)=0.001 | P(1)=0.999 | V=1.000 | TD=0.000
# Episode  500 | P(0)=0.001 | P(1)=0.999 | V=1.000 | TD=0.000
# Episode  600 | P(0)=0.001 | P(1)=0.999 | V=1.000 | TD=0.000
# Episode  700 | P(0)=0.001 | P(1)=0.999 | V=1.000 | TD=0.000
# Episode  800 | P(0)=0.001 | P(1)=0.999 | V=1.000 | TD=0.000
# Episode  900 | P(0)=0.001 | P(1)=0.999 | V=1.000 | TD=0.000
# Episode 1000 | P(0)=0.001 | P(1)=0.999 | V=1.000 | TD=0.000
#
# Training finished successfully.
